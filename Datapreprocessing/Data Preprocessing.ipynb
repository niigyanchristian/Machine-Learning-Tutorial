# %% [markdown]
# # Steps of preprocessing of Data
# #### Step 1 : Import library
# #### Step 2 : Read Dataset
# #### Step 3 : Data Sanity Check
# #### Step 4 : Exploratory Data Analysis (EDA)
# #### Step 5 : Handling Missing Values
# #### Step 6 : Outliers treatments
# #### Step 7 : Duplicates and Garbage value treatments
# #### Step 8 : Data Encoding

# %% [markdown]
# # Import library

# %%
# Import library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("Dataset.csv")

# %%
# head
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# tail
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df = df.drop('Country',axis=1)

# %%
df.head(435)
# Out:
#      Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0    2015  Developing              65.0            263.0             62
# 1    2014  Developing              59.9            271.0             64
# 2    2013  Developing              59.9            268.0             66
# 3    2012  Developing              59.5            272.0             69
# 4    2011  Developing              59.2            275.0             71
# ..    ...         ...               ...              ...            ...
# 430  2001  Developing              51.3            385.0             25
# 431  2000  Developing              58.0            386.0             25
# 432  2015  Developing              53.3            397.0             57
# 433  2014  Developing              52.8             47.0             58
# 434  2013  Developing              52.3            412.0             59
#
#      Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %% [markdown]
# # Data Sanity Check

# %%
# shape
df.shape
# Out:
# (2938, 21)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             2938 non-null   int64
#  1   Status                           2938 non-null   object
#  2   Life expectancy                  2928 non-null   float64
#  3   Adult Mortality                  2928 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2744 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
# ...

# %%
# Finding the missing values
df.isnull().sum()
# Out:
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Percentage of missing data for each column
print("Missing values before handling the missing values")
data = df.isnull().sum()/df.shape[0]*100
data
# Out:
# Missing values before handling the missing values
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# finding duplicates
df. duplicated().sum()
# Out:
# 0

# %%
# Identify garbage value
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("*******"*20)
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64
# ********************************************************************************************************************************************

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# View Statistics
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %%
df.describe(include="object").T
# Out:
#        count unique         top  freq
# Status  2938      2  Developing  2426

# %%
# histogram to understand the distribution
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
# Indentify outlier using the Boxplot
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
# Scatter plot
cols =['Year', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']

for col in cols:
    sns.scatterplot(data=df,x=col, y='Life expectancy ')
    plt.title(f'Scatter Plot for {col}')
    plt.xlabel(col)
    plt.ylabel('Life expectancy')
    plt.show()

# %%
# coleration
coleration = df.select_dtypes(include="number").corr()
coleration
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
# Heat map

plt.figure(figsize=(15,15))
sns.heatmap(coleration, annot=True, fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %%
df.head(435)
# Out:
#      Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0    2015  Developing              65.0            263.0             62
# 1    2014  Developing              59.9            271.0             64
# 2    2013  Developing              59.9            268.0             66
# 3    2012  Developing              59.5            272.0             69
# 4    2011  Developing              59.2            275.0             71
# ..    ...         ...               ...              ...            ...
# 430  2001  Developing              51.3            385.0             25
# 431  2000  Developing              58.0            386.0             25
# 432  2015  Developing              53.3            397.0             57
# 433  2014  Developing              52.8             47.0             58
# 434  2013  Developing              52.3            412.0             59
#
#      Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# # Handling Missing Values

# %%
for i in ['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
#     df[i].fillna(df[i].mean(),inplace=True)
        df[i].fillna(df[i].mean(), inplace=True)

# %%
df.head(435)
# Out:
#      Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0    2015  Developing              65.0            263.0             62
# 1    2014  Developing              59.9            271.0             64
# 2    2013  Developing              59.9            268.0             66
# 3    2012  Developing              59.5            272.0             69
# 4    2011  Developing              59.2            275.0             71
# ..    ...         ...               ...              ...            ...
# 430  2001  Developing              51.3            385.0             25
# 431  2000  Developing              58.0            386.0             25
# 432  2015  Developing              53.3            397.0             57
# 433  2014  Developing              52.8             47.0             58
# 434  2013  Developing              52.3            412.0             59
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
# Finding the missing values

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer
imputed= KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
    df[i] = imputed.fit_transform(df[[i]])

# %%
# Finding the missing values

# %% [markdown]
# # Outliers treatments

# %%
def wisker(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
# wisker(df['Life expectancy '])

# %%
# for i in ['Total expenditure','GDP',' thinness  1-19 years',' thinness 5-9 years']:
#     lw,uw = wisker(df[i])
#     df[i]=np.where(df[i]<lw,lw,df[i])
#     df[i]=np.where(df[i]>uw,uw,df[i])

# %%
# # Indentify outlier using the Boxplot
# for i in ['Total expenditure','GDP',' thinness  1-19 years',' thinness 5-9 years']:
#     sns.boxplot(data=df,x=i)
#     plt.show()

# %% [markdown]
# # Duplicates and Garbage value treatments

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Data Encoding

# %% [markdown]
# #### Nominal Encoding
# ![image.png](attachment:image.png)
#
# #### Ordinal Encoding
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dataset = pd.get_dummies(data=df,columns=["Status"],drop_first=True)

# %%
dataset.to_csv('Modified_Dataset.csv', index=False)
