# %% [markdown]
# # Step 1: Import Libraries

# %% [markdown]
# # Step 2: Load the Dataset

# %% [markdown]
# # Step 3: Split the Data

# %% [markdown]
# # Step 4: Feature Scaling

# %% [markdown]
# # Step 5: Initialize and Train the Model

# %% [markdown]
# # Step 6: Make Predictions

# %% [markdown]
# # Step 7: Evaluate the Model

# %% [markdown]
# **Precision:** How many detected elements were relevant.
# ![Screenshot%202024-03-04%20083621.png](attachment:Screenshot%202024-03-04%20083621.png)
# **Recall:** How many relevant elements were detected.

# %% [markdown]
# # Step 8: Save the model to a file
